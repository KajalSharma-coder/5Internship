# %%
#1) Practice Print Statement
#(a) Print with Multiple Objects
name = "Amit Kumar"
age = 25
print("Name:", name, "Age:", age)
#(b) Print with Separator
print("Hello", "World", sep="-")
#(c) Print with End Parameter
print("Hello", end=" ")
print("World!")
# Out:
# Name: Amit Kumar Age: 25
# Hello-World
# Hello World!

# %%
#2) Ask User Name and Display Greeting Message
name = input("Enter your name: ")
print("Hello, " + name + "! Welcome to Python programming.")
# Out:
# Hello, Kajal! Welcome to Python programming.
