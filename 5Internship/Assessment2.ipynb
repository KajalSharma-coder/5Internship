# %%
#1) Student Name, Class, Total Marks and Percentage
name = input("Enter Student Name: ")
student_class = input("Enter Class: ")

m1 = float(input("Enter Marks of Subject 1: "))
m2 = float(input("Enter Marks of Subject 2: "))
m3 = float(input("Enter Marks of Subject 3: "))
m4 = float(input("Enter Marks of Subject 4: "))
m5 = float(input("Enter Marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = (total / 500) * 100

print("\n----- RESULT -----")
print("Name:", name)
print("Class:", student_class)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# ----- RESULT -----
# Name: Kajal
# Class: 12
# Total Marks: 432.0
# Percentage: 86.4 %

# %%
#2) String Concatenation and String Methods
str1 = input("Enter First String: ")
str2 = input("Enter Second String: ")

result = str1 + " " + str2

print("\nConcatenated String:", result)

print("lower():", result.lower())
print("upper():", result.upper())
print("title():", result.title())
print("swapcase():", result.swapcase())
print("capitalize():", result.capitalize())
print("casefold():", result.casefold())

print("center(50):", result.center(50))
print("count('a'):", result.count('a'))

print("endswith('a'):", result.endswith('a'))
print("find('a'):", result.find('a'))

print("isalnum():", result.isalnum())
print("isdigit():", result.isdigit())
print("isnumeric():", result.isnumeric())
print("isspace():", result.isspace())

print("replace('a','@'):", result.replace('a', '@'))
# Out:
# Concatenated String: Hello guys My name is kajal
# lower(): hello guys my name is kajal
# upper(): HELLO GUYS MY NAME IS KAJAL
# title(): Hello Guys My Name Is Kajal
# swapcase(): hELLO GUYS mY NAME IS KAJAL
# capitalize(): Hello guys my name is kajal
# casefold(): hello guys my name is kajal
# center(50):            Hello guys My name is kajal
# count('a'): 3
# endswith('a'): False
# find('a'): 15
# isalnum(): False
# isdigit(): False
# isnumeric(): False
# isspace(): False
# replace('a','@'): Hello guys My n@me is k@j@l

# %%
#3) Practice Assignment Operators
a = 20

print("Initial Value =", a)

a += 10
print("After += :", a)

a -= 5
print("After -= :", a)

a *= 2
print("After *= :", a)

a /= 5
print("After /= :", a)

a %= 3
print("After %= :", a)

a **= 2
print("After **= :", a)

a //= 2
print("After //= :", a)
# Out:
# Initial Value = 20
# After += : 30
# After -= : 25
# After *= : 50
# After /= : 10.0
# After %= : 1.0
# After **= : 1.0
# After //= : 0.0

# %%
#4) Student Result with Grade Using Conditional Statements
name = input("Enter Student Name: ")
student_class = input("Enter Class: ")

m1 = float(input("Enter Marks of Subject 1: "))
m2 = float(input("Enter Marks of Subject 2: "))
m3 = float(input("Enter Marks of Subject 3: "))
m4 = float(input("Enter Marks of Subject 4: "))
m5 = float(input("Enter Marks of Subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = (total / 500) * 100

if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'F'

print("\n----- RESULT -----")
print("Name:", name)
print("Class:", student_class)
print("Total Marks:", total)
print("Percentage:", round(percentage, 2), "%")
print("Grade:", grade)
# Out:
# ----- RESULT -----
# Name: Kajal
# Class: 10
# Total Marks: 433.0
# Percentage: 86.6 %
# Grade: A
