# %%
print("hello")
# Out:
# hello

# %%
print('hello',"python",sep="-",end=" ")
print("""welcome to python
      python is easy to learn
      1
      2
      3""")
# Out:
# hello-python welcome to python
#       python is easy to learn
#       1
#       2
#       3

# %%
a=10
b=int(10.0)
print(id(a))
print(id(b))
# Out:
# 140736757793992
# 140736757793992

# %%
a="This is python"
print(a,type(a))
a=10
print(a,type(a))
# Out:
# This is python <class 'str'>
# 10 <class 'int'>

# %%
n1 =input("enter number 1:")
print(n1)
# Out:
# 11

# %%
n1 = int(input("enter number 1:"))
print(type(n1))
# Out:
# <class 'int'>

# %%
price = 200
tax = 18
print(f"The price is {price + (price*tax/100)} rupees")
# Out:
# The price is 236.0 rupees

# %%
x=str(20)
x= 23 + 4j
print(type(x))
# Out:
# <class 'complex'>

# %%
a= "Hello"
b= " Python"
print(a.lower()+" "+b.upper())
# Out:
# hello  PYTHON

# %%
a="kajal"
#capitalize the first letter
print(a.title())
print(a.capitalize())
# Out:
# Kajal
# Kajal

# %%
a="helooo bachooo"
b= "Kajal"
print(a.center(60))
print(a.count("o"))
print(a.expandtabs(tabsize=40))
print(a.find("o"))
print(b.index("l"))
print(a.isalnum())
print(b.isalpha())
seq = ("a","b")
print(a.join(seq))
print(a.ljust(40,"."))
print(a.rjust(40,"."))
print((a.lstrip("h")).rstrip())
print(a.rstrip("o"))
print(a.replace("o","io"))
# Out:
#                        helooo bachooo
# 6
# helooo bachooo
# 3
# 4
# False
# True
# ahelooo bachooob
# helooo bachooo..........................
# ..........................helooo bachooo
# elooo bachooo
# helooo bach
# helioioio bachioioio

# %%
str ="this is python!!"
l="rpton"
e="12345"
encoding = str.maketrans(l,e)
print(str.translate(encoding))
# Out:
# 3his is 2y3h45!!

# %%
a=10
b=20
print(a!=b)
print(a>b)
print(a<b)
print(not a!=b)
print(a is not b)
print(a is b)
# Out:
# True
# False
# True
# False
# True
# False

# %%
a="This is python"
b="This"
if(b in a):
    print("b is present in a")
# Out:
# b is present in a

# %%
a="This is python"
b="Thiz"
if(b not in a):
    print("b is not present in a")

# %%
a=10
if(a>10):
  print("a is greater than 10")
  if(a>12):
    print("okk")
  else:
    print("okkkkkkkkk")
else:
  print("less")
# Out:
# less

# %%
n=11
print("n is greater than 10") if n>10 else print("n is less than or equal to 10")
# Out:
# n is greater than 10

# %%
#range(start,stop,step)
for i in range(2,10,3):
  print(i)
# Out:
# 2
# 5
# 8

# %%
for x in range(5,5,-2):
  print(x)
else: 
  print("loop is ended")
# Out:
# loop is ended

# %%
for i in range(10,0,-1):
  if(i<5):
    break
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %%
a= input("enter a number:")
for i in range(1,11):
  print(int(a), "*", i, " = ",(int(a) * i))
# Out:
# 5 * 1  =  5
# 5 * 2  =  10
# 5 * 3  =  15
# 5 * 4  =  20
# 5 * 5  =  25
# 5 * 6  =  30
# 5 * 7  =  35
# 5 * 8  =  40
# 5 * 9  =  45
# 5 * 10  =  50

# %%
for i in range(5,0,-1):
  for j in range(5):
    print(i,j,sep="--")
# Out:
# 5--0
# 5--1
# 5--2
# 5--3
# 5--4
# 4--0
# 4--1
# 4--2
# 4--3
# 4--4
# 3--0
# 3--1
# 3--2
# 3--3
# 3--4
# 2--0
# 2--1
# 2--2
# 2--3
# 2--4
# 1--0
# 1--1
# 1--2
# 1--3
# 1--4

# %%
str = "Python Program"
print(str[-1])
print(str[0:5:2])
print(str[0:4])
print(str[2::9])
for x in str:
  print(x)

count = 0
for i in str:
    count = count + 1
print("Length is:", count)

print(ord("P"))
print(chr(75))
# Out:
# m
# Pto
# Pyth
# tr
# P
# y
# t
# h
# o
# n
#
# P
# r
# o
# g
# r
# a
# m
# Length is: 14
# 80
# K
